# %%
import pandas as pd

# %%
pd.read_excel('C:\Users\kumak\iNeuron classes\Resources\Live Class\pandas\Attribute DataSet.xlsx')
# Out:
#   Cell In[2], line 1
#     pd.read_excel('C:\Users\kumak\iNeuron classes\Resources\Live Class\pandas\Attribute DataSet.xlsx')
#                                                                                                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# resolved above error with 'r' infront of file path.
# refer below
https://stackoverflow.com/questions/37400974/error-unicode-error-unicodeescape-codec-cant-decode-bytes-in-position-2-3
# Out:
#   Cell In[3], line 3
#     https://stackoverflow.com/questions/37400974/error-unicode-error-unicodeescape-codec-cant-decode-bytes-in-position-2-3
#           ^
# SyntaxError: invalid syntax

# %%
pd.read_excel(r'C:\Users\kumak\iNeuron classes\Resources\Live Class\pandas\Attribute DataSet.xlsx')
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
#  instead of providing path or location, we can upload the file in current working directory and use, 
#  refer below.

# %%
pd.read_csv('haberman (1).csv')
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %%
df = pd.read_excel(r'C:\Users\kumak\iNeuron classes\Resources\Live Class\pandas\Attribute DataSet.xlsx')

# %%
#  dataframe : (same as sql table)
#  a tabular structure, 

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
# how to handle 'nul' value.
# from different sheets, i need to review data in excel?

# %%
df1= pd.read_excel(r'C:\Users\kumak\iNeuron classes\Resources\Live Class\pandas\Attribute DataSet.xlsx', sheet_name= 'sample_sheet', header = 0, names = ['A', 'B','C']
)

# %%
df1
# Out:
#                      A    B  C
# 1  khai kj jj    csjco    1  0
# 2  wdwdq       kcsh cs    0  1
# 3  khai kj jj    csjco    1  1
# 4  cXQDq         csjco    0  0
# 5  khai kj jj     qceq    1  1
# 6  d cqd         csjco    0  0
# 7  khai kj jj    csjco    1  1
# 8  ac dw          cqeq    0  0
# 9  cqd           csjco    1  0
# 10 khai kj jj    csjco    0  1
# 11 khai kj jj      cqd    1  0
# 12 c qdq         csjco    1  0
# 13 khai kj jj    cqedq    0  0
# 14 khai kj jj    csjco    1  1
# 15 khai kj jj    csjco  cqe  0
# 16 khai kj jj    csjco    1  0
# 17 khai kj jj    csjco    0  1
# 18 khai kj jj     cqeq    1  0
# 19 khai kj jj    csjco    0  1
# 20 khai kj jj      cqe    1  0
# 21 khai kj jj    csjco    1  0
# 22 khai kj jj        q    0  1
# 23 khai kj jj    csjco    1  0
# 24 khai kj jj    csjco    1  1
# 25 khai kj jj    csjco    1  0
# 26 khai kj jj      cqe    0  1
# 27 khai kj jj    csjco    1  0
# 28 khai kj jj    csjco    1  1
# 29 khai kj jj    csjco    0  0

# %%
#  pandas takes first row record as column header by default

# %%
df.head(2)
# Out:
#      Dress_ID   Style Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852    Sexy   Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089  Casual   Low     0.0    L  Summer   o-neck        Petal
#
#   waiseline    Material FabricType Decoration Pattern Type  Recommendation
# 0    empire         NaN    chiffon    ruffles       animal               1
# 1   natural  microfiber        NaN    ruffles       animal               0

# %%
df.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire            NaN    chiffon     ruffles       animal               1
# 1   natural     microfiber        NaN     ruffles       animal               0
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
df.head(20)
# Out:
#     s.no        test     many one   must
# 0      1  khai kj jj    csjco    1     0
# 1      2       wdwdq  kcsh cs    0     1
# 2      3  khai kj jj    csjco    1     1
# 3      4       cXQDq    csjco    0     0
# 4      5  khai kj jj     qceq    1     1
# 5      6       d cqd    csjco    0     0
# 6      7  khai kj jj    csjco    1     1
# 7      8       ac dw     cqeq    0     0
# 8      9         cqd    csjco    1     0
# 9     10  khai kj jj    csjco    0     1
# 10    11  khai kj jj      cqd    1     0
# 11    12       c qdq    csjco    1     0
# 12    13  khai kj jj    cqedq    0     0
# 13    14  khai kj jj    csjco    1     1
# 14    15  khai kj jj    csjco  cqe     0
# 15    16  khai kj jj    csjco    1     0
# 16    17  khai kj jj    csjco    0     1
# 17    18  khai kj jj     cqeq    1     0
# 18    19  khai kj jj    csjco    0     1
# 19    20  khai kj jj      cqe    1     0

# %%
df.tail()
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 495  713391965  Casual      Low     4.7     M  Spring     o-neck         full
# 496  722565148    Sexy      Low     4.3  free  Summer     o-neck         full
# 497  532874347  Casual  Average     4.7     M  Summer     v-neck         full
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline  Material  FabricType Decoration Pattern Type  Recommendation
# 495   natural  polyster         NaN        NaN        solid               1
# 496    empire    cotton         NaN        NaN          NaN               0
# 497    empire    cotton         NaN       lace        solid               1
# 498    empire      silk  broadcloth   applique        print               1
# 499    empire    cotton    Corduroy       lace        solid               0

# %%
df.tail(10)
# Out:
#       Dress_ID     Style    Price  Rating  Size  Season   NeckLine  \
# 490  641665398    Casual      Low     4.8  free  winter    bowneck
# 491  964917582    Casual  Average     5.0     L  Summer     o-neck
# 492  859922576      cute  Average     4.6     M  Spring     o-neck
# 493  817353671  bohemian      Low     4.6  free  Summer     o-neck
# 494  990559192     Brief  Average     4.7     M  winter     o-neck
# 495  713391965    Casual      Low     4.7     M  Spring     o-neck
# 496  722565148      Sexy      Low     4.3  free  Summer     o-neck
# 497  532874347    Casual  Average     4.7     M  Summer     v-neck
# 498  655464934    Casual  Average     4.6     L  winter  boat-neck
# 499  919930954    Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline  Material  FabricType Decoration Pattern Type  \
# 490         full   natural  polyster     chiffon        bow        solid
# 491    sleevless   natural    cotton         NaN        NaN          NaN
# ...

# %%
dataframe2 = pd.read_csv(r"C:\Users\kumak\iNeuron classes\Resources\Live Class\pandas\haberman.csv", header = 0, names = ['Age', "Patient's year of operaion", 'No of Positive nodes', 'SUrvival status'])

# %%
dataframe2
# Out:
#      Age  Patient's year of operaion  No of Positive nodes  SUrvival status
# 0     30                          62                     3                1
# 1     30                          65                     0                1
# 2     31                          59                     2                1
# 3     31                          65                     4                1
# 4     33                          58                    10                1
# ..   ...                         ...                   ...              ...
# 300   75                          62                     1                1
# 301   76                          67                     0                1
# 302   77                          65                     3                1
# 303   78                          65                     1                2
# 304   83                          58                     2                2
#
# [305 rows x 4 columns]

# %%
dataframe3 = pd.read_csv(r"C:\Users\kumak\iNeuron classes\Resources\Live Class\pandas\test_delimitor_dataset.csv", delimiter = '@')

# %%
dataframe3
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %%
dataframe_from_git = pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/Smarket.csv")

# %%
dataframe_from_git
# Out:
#       Year   Lag1   Lag2   Lag3   Lag4   Lag5   Volume  Today Direction
# 0     2001  0.381 -0.192 -2.624 -1.055  5.010  1.19130  0.959        Up
# 1     2001  0.959  0.381 -0.192 -2.624 -1.055  1.29650  1.032        Up
# 2     2001  1.032  0.959  0.381 -0.192 -2.624  1.41120 -0.623      Down
# 3     2001 -0.623  1.032  0.959  0.381 -0.192  1.27600  0.614        Up
# 4     2001  0.614 -0.623  1.032  0.959  0.381  1.20570  0.213        Up
# ...    ...    ...    ...    ...    ...    ...      ...    ...       ...
# 1245  2005  0.422  0.252 -0.024 -0.584 -0.285  1.88850  0.043        Up
# 1246  2005  0.043  0.422  0.252 -0.024 -0.584  1.28581 -0.955      Down
# 1247  2005 -0.955  0.043  0.422  0.252 -0.024  1.54047  0.130        Up
# 1248  2005  0.130 -0.955  0.043  0.422  0.252  1.42236 -0.298      Down
# 1249  2005 -0.298  0.130 -0.955  0.043  0.422  1.38254 -0.489      Down
#
# [1250 rows x 9 columns]

# %%
df_from_web = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
df_from_web
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df_from_web)
# Out:
# list

# %%
df_from_web[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
len(df_from_web)
# Out:
# 1

# %%
df_json_link = pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
df_json_link
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
df_json_link.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'body', 'reactions', 'timeline_url',
#        'performed_via_github_app', 'state_reason', 'draft', 'pull_request'],
#       dtype='object')

# %%
df_json_link['user']
# Out:
# 0     {'login': 'kalekundert', 'id': 298132, 'node_i...
# 1     {'login': 'luke396', 'id': 77875500, 'node_id'...
# 2     {'login': 'Tialo', 'id': 65392801, 'node_id': ...
# 3     {'login': 'KladeRe', 'id': 81648517, 'node_id'...
# 4     {'login': 'lithomas1', 'id': 47963215, 'node_i...
# 5     {'login': 'nagaprakashv', 'id': 13671867, 'nod...
# 6     {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 7     {'login': 'lukemanley', 'id': 8519523, 'node_i...
# 8     {'login': 'lukemanley', 'id': 8519523, 'node_i...
# 9     {'login': 'lukemanley', 'id': 8519523, 'node_i...
# 10    {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 11    {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 12    {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 13    {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 14    {'login': 'DeaMariaLeon', 'id': 11835246, 'nod...
# 15    {'login': 'DeaMariaLeon', 'id': 11835246, 'nod...
# 16    {'login': 'dannyi96', 'id': 15380498, 'node_id...
# ...

# %%
df_json_link['user'][0]
# Out:
# {'login': 'kalekundert',
#  'id': 298132,
#  'node_id': 'MDQ6VXNlcjI5ODEzMg==',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/298132?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/kalekundert',
#  'html_url': 'https://github.com/kalekundert',
#  'followers_url': 'https://api.github.com/users/kalekundert/followers',
#  'following_url': 'https://api.github.com/users/kalekundert/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/kalekundert/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/kalekundert/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/kalekundert/subscriptions',
#  'organizations_url': 'https://api.github.com/users/kalekundert/orgs',
#  'repos_url': 'https://api.github.com/users/kalekundert/repos',
#  'events_url': 'https://api.github.com/users/kalekundert/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/kalekundert/received_events',
# ...

# %%
df_json_link['title']
# Out:
# 0     BUG: "table name" form of  `pd.read_sql()` doe...
# 1     DOC: Imporve `json_normalize` record_prefix an...
# 2     BUG: Docs does not build on macos, due to EOFE...
# 3               Fixed groupby error with nullable types
# 4        DEPR: Positional arguments in to_* I/O methods
# 5     ENH: a readable sample function or an improvement
# 6                       DEPR: idxmin/idxmax with all-NA
# 7     CLN/ASV: remove downcast param (deprecated) fr...
# 8          PERF: DataFrame.transpose for pyarrow-backed
# 9                               PERF: ArrowDtype.__eq__
# 10                        CI/TST: Address some warnings
# 11                     DOC: Simplify contributing intro
# 12                     DEPR: Series.argsort NA behavior
# 13                      CI: Try out pre-commit.ci again
# 14                    DOC: Fixing EX01 - Added examples
# 15    DOC: Removed InvalidComparison and LossySetIte...
# 16    FIX: query() and isin() fail on period type co...
# ...

# %%
df_attributes = pd.read_excel(r"C:\Users\kumak\iNeuron classes\Resources\Live Class\pandas\Attribute DataSet.xlsx")

# %%
df_attributes
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
#  convert into json

df_attributes.to_json('test.json')

# %%
pwd
# Out:
# 'C:\\Users\\kumak\\iNeuron classes\\Pandas'

# %%
#  creating file 
df_attributes.to_csv(r"C:\Users\kumak\Desktop\test.csv")

# %%
#  sep = and delimitor while creating the file 
df_attributes.to_csv(r"C:\Users\kumak\Desktop\test1234.csv", sep = '#')

# %%
df_attributes.to_csv(r"C:\Users\kumak\Desktop\test12345.csv", index = False)

# %% [markdown]
# TASK
#
# we have this attributes data sets, and dress sales data base.
# connected based on dress id.
#
#
# Mysql :
#
#     1. Create a  table attribute dataset and dress dataset
#     2. Do a bulk load for these two table for respective dataset
#     3. read these dataset in pandas as a dataframe
#     4. Convert attribute dataset in json format
#     5. Store this dataset into mongodb
#     6. in sql task try to perform left join operation with attrubute dataset and dress dataset on column Dress_ID
#     7. Write a sql query to find out how many unique dress that we have based on dress id
#     8. Try to find out how mnay dress is having recommendation 0
#     9. Try to find out total dress sell for individual dress id
#     10. Try to find out a third highest most selling dress id
