# %%
import pandas as pd

# %%
agentlogin = pd.read_csv(r"C:\Users\kumak\iNeuron classes\Resources\Live Class\pandas\AgentLogingReport.csv")

# %%
agentperfom = pd.read_csv(r"C:\Users\kumak\iNeuron classes\Resources\Live Class\pandas\AgentPerformance.csv")

# %%
agentlogin
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
# [1000 rows x 6 columns]

# %%
agentperfom
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
agentperfom.head()
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1  7/30/2022   Prerna Singh           11               0:00:38
# 1      2  7/30/2022  Nandani Gupta           11               0:01:15
# 2      3  7/30/2022     Ameya Jain           14               0:00:30
# 3      4  7/30/2022  Mahesh Sarade           14               0:01:04
# 4      5  7/30/2022         Swati            14               0:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback
# 0                 0:04:20            4.11               9
# 1                 0:28:25            3.14               7
# 2                 0:11:36            4.55              11
# 3                 0:15:46            4.71               7
# 4                 0:16:33            3.67               6

# %%
agentperfom.head(10)
# Out:
#    SL No       Date       Agent Name  Total Chats Average Response Time  \
# 0      1  7/30/2022     Prerna Singh           11               0:00:38
# 1      2  7/30/2022    Nandani Gupta           11               0:01:15
# 2      3  7/30/2022       Ameya Jain           14               0:00:30
# 3      4  7/30/2022    Mahesh Sarade           14               0:01:04
# 4      5  7/30/2022           Swati            14               0:01:11
# 5      6  7/30/2022          Mukesh             9               0:00:34
# 6      7  7/30/2022  Saikumarreddy N           15               0:00:31
# 7      8  7/30/2022    Sanjeev Kumar           12               0:00:55
# 8      9  7/30/2022   Shubham Sharma           13               0:01:31
# 9     10  7/30/2022     Nishtha Jain           20               0:00:59
#
#   Average Resolution Time  Average Rating  Total Feedback
# 0                 0:04:20            4.11               9
# 1                 0:28:25            3.14               7
# ...

# %%
agentperfom.tail()
# Out:
#       SL No      Date          Agent Name  Total Chats Average Response Time  \
# 2155   2156  7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157  7/1/2022             Nitin M            0               0:00:00
# 2157   2158  7/1/2022              Vivek             0               0:00:00
# 2158   2159  7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160  7/1/2022  Chaitra K Hiremath            0               0:00:00
#
#      Average Resolution Time  Average Rating  Total Feedback
# 2155                 0:00:00             0.0               0
# 2156                 0:00:00             0.0               0
# 2157                 0:00:00             0.0               0
# 2158                 0:00:00             0.0               0
# 2159                 0:00:00             0.0               0

# %%
agentperfom.tail(10)
# Out:
#       SL No      Date          Agent Name  Total Chats Average Response Time  \
# 2150   2151  7/1/2022              Spuri             0               0:00:00
# 2151   2152  7/1/2022       Suraj S Bilgi            0               0:00:00
# 2152   2153  7/1/2022       Nandani Gupta            0               0:00:00
# 2153   2154  7/1/2022           Shivan_S             0               0:00:00
# 2154   2155  7/1/2022       Mahesh Sarade            0               0:00:00
# 2155   2156  7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157  7/1/2022             Nitin M            0               0:00:00
# 2157   2158  7/1/2022              Vivek             0               0:00:00
# 2158   2159  7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160  7/1/2022  Chaitra K Hiremath            0               0:00:00
#
#      Average Resolution Time  Average Rating  Total Feedback
# 2150                 0:00:00             0.0               0
# ...

# %%
agentlogin.tail()
# Out:
#      SL No           Agent       Date Login Time Logout Time   Duration
# 995    996    Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997         Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998  Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999    Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000           Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20

# %%
agentlogin.columns
# Out:
# Index(['SL No', 'Agent', 'Date', 'Login Time', 'Logout Time', 'Duration'], dtype='object')

# %%
agentlogin['Date']
# Out:
# 0      30-Jul-22
# 1      30-Jul-22
# 2      30-Jul-22
# 3      30-Jul-22
# 4      30-Jul-22
#          ...
# 995    20-Jul-22
# 996    20-Jul-22
# 997    20-Jul-22
# 998    20-Jul-22
# 999    01-Jul-22
# Name: Date, Length: 1000, dtype: object

# %%
type(agentlogin['Date'])
# Out:
# pandas.core.series.Series

# %%
type(agentlogin['Duration'])
# Out:
# pandas.core.series.Series

# %%
agentlogin.dtypes
# Out:
# SL No           int64
# Agent          object
# Date           object
# Login Time     object
# Logout Time    object
# Duration       object
# dtype: object

# %%
agentlogin[['SL No','Agent']]  #  mark it as list, and do multiple
# Out:
#      SL No               Agent
# 0        1  Shivananda Sonwane
# 1        2      Khushboo Priya
# 2        3       Nandani Gupta
# 3        4     Hrisikesh Neogi
# 4        5              Mukesh
# ..     ...                 ...
# 995    996        Manjunatha A
# 996    997             Bharath
# 997    998      Khushboo Priya
# 998    999        Nishtha Jain
# 999   1000               Tarun
#
# [1000 rows x 2 columns]

# %%
agentlogin['Date']
# Out:
# 0      30-Jul-22
# 1      30-Jul-22
# 2      30-Jul-22
# 3      30-Jul-22
# 4      30-Jul-22
#          ...
# 995    20-Jul-22
# 996    20-Jul-22
# 997    20-Jul-22
# 998    20-Jul-22
# 999    01-Jul-22
# Name: Date, Length: 1000, dtype: object

# %%
type(agentlogin['Date'])
# Out:
# pandas.core.series.Series

# %%
agentlogin[['Date']]
# Out:
#           Date
# 0    30-Jul-22
# 1    30-Jul-22
# 2    30-Jul-22
# 3    30-Jul-22
# 4    30-Jul-22
# ..         ...
# 995  20-Jul-22
# 996  20-Jul-22
# 997  20-Jul-22
# 998  20-Jul-22
# 999  01-Jul-22
#
# [1000 rows x 1 columns]

# %%
type(agentlogin[['Date']])
# Out:
# pandas.core.frame.DataFrame

# %%
#  if we have more than 1 coulms, better use list parameter

# %%
agentperfom.columns
# Out:
# Index(['SL No', 'Date', 'Agent Name', 'Total Chats', 'Average Response Time',
#        'Average Resolution Time', 'Average Rating', 'Total Feedback'],
#       dtype='object')

# %%
agentperfom[['SL No','Agent Name','Total Chats', 'Average Rating' ]]
# Out:
#       SL No          Agent Name  Total Chats  Average Rating
# 0         1        Prerna Singh           11            4.11
# 1         2       Nandani Gupta           11            3.14
# 2         3          Ameya Jain           14            4.55
# 3         4       Mahesh Sarade           14            4.71
# 4         5              Swati            14            3.67
# ...     ...                 ...          ...             ...
# 2155   2156   Sowmiya Sivakumar            0            0.00
# 2156   2157             Nitin M            0            0.00
# 2157   2158              Vivek             0            0.00
# 2158   2159       Ayushi Mishra            0            0.00
# 2159   2160  Chaitra K Hiremath            0            0.00
#
# [2160 rows x 4 columns]

# %%
agentperfom.head()
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1  7/30/2022   Prerna Singh           11               0:00:38
# 1      2  7/30/2022  Nandani Gupta           11               0:01:15
# 2      3  7/30/2022     Ameya Jain           14               0:00:30
# 3      4  7/30/2022  Mahesh Sarade           14               0:01:04
# 4      5  7/30/2022         Swati            14               0:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback
# 0                 0:04:20            4.11               9
# 1                 0:28:25            3.14               7
# 2                 0:11:36            4.55              11
# 3                 0:15:46            4.71               7
# 4                 0:16:33            3.67               6

# %%
agentperfom.describe()
# Out:
#              SL No  Total Chats  Average Rating  Total Feedback
# count  2160.000000  2160.000000     2160.000000     2160.000000
# mean   1080.500000     6.814815        1.460963        4.286574
# std     623.682612    11.705233        2.074763        7.412594
# min       1.000000     0.000000        0.000000        0.000000
# 25%     540.750000     0.000000        0.000000        0.000000
# 50%    1080.500000     0.000000        0.000000        0.000000
# 75%    1620.250000    13.000000        4.120000        7.000000
# max    2160.000000    97.000000        5.000000       56.000000

# %%
agentperfom.dtypes
# Out:
# SL No                        int64
# Date                        object
# Agent Name                  object
# Total Chats                  int64
# Average Response Time       object
# Average Resolution Time     object
# Average Rating             float64
# Total Feedback               int64
# dtype: object

# %%
# the 'describe' function provides description for only numerical values i.e. 'int , float ' types

# %% [raw]
# # on above, based on 'description', if all coulmns's count matches.. we can say there is no 'null' volumes
#
# average rating is 1.460963 (mean), average of total chats 6.814815 (mean)
#
# std - Standard deviation; square root of variences; deviations from the mean.
#
# min - minimum ; minimum of average rating is 0.0, minimum of total feedback 0.00
# max - maximum ; maximum rating is 5, maximum of total feed back is 56.00
#
# 25% -

# %%
agentperfom.dtypes == 'object'
# Out:
# SL No                      False
# Date                        True
# Agent Name                  True
# Total Chats                False
# Average Response Time       True
# Average Resolution Time     True
# Average Rating             False
# Total Feedback             False
# dtype: bool

# %%
agentperfom.dtypes[agentperfom.dtypes == 'object']
# Out:
# Date                       object
# Agent Name                 object
# Average Response Time      object
# Average Resolution Time    object
# dtype: object

# %%
agentperfom.dtypes[agentperfom.dtypes == 'object'].index
# Out:
# Index(['Date', 'Agent Name', 'Average Response Time',
#        'Average Resolution Time'],
#       dtype='object')

# %%
agentperfom[agentperfom.dtypes[agentperfom.dtypes == 'object'].index]
# Out:
#            Date          Agent Name Average Response Time  \
# 0     7/30/2022        Prerna Singh               0:00:38
# 1     7/30/2022       Nandani Gupta               0:01:15
# 2     7/30/2022          Ameya Jain               0:00:30
# 3     7/30/2022       Mahesh Sarade               0:01:04
# 4     7/30/2022              Swati                0:01:11
# ...         ...                 ...                   ...
# 2155   7/1/2022   Sowmiya Sivakumar               0:00:00
# 2156   7/1/2022             Nitin M               0:00:00
# 2157   7/1/2022              Vivek                0:00:00
# 2158   7/1/2022       Ayushi Mishra               0:00:00
# 2159   7/1/2022  Chaitra K Hiremath               0:00:00
#
#      Average Resolution Time
# 0                    0:04:20
# 1                    0:28:25
# 2                    0:11:36
# 3                    0:15:46
# 4                    0:16:33
# ...                      ...
# 2155                 0:00:00
# ...

# %%
agentperfom[agentperfom.dtypes[agentperfom.dtypes == 'object'].index].describe()
# Out:
#              Date   Agent Name Average Response Time Average Resolution Time
# count        2160         2160                  2160                    2160
# unique         30           70                   144                     612
# top     7/30/2022  Rishav Dash               0:00:00                 0:00:00
# freq           72           60                  1433                    1415

# %%
agentperfom.dtypes
# Out:
# SL No                        int64
# Date                        object
# Agent Name                  object
# Total Chats                  int64
# Average Response Time       object
# Average Resolution Time     object
# Average Rating             float64
# Total Feedback               int64
# dtype: object

# %%
agentperfom.dtypes[agentperfom.dtypes=='float64']
# Out:
# Average Rating    float64
# dtype: object

# %%
agentperfom.dtypes[agentperfom.dtypes=='float64'].index
# Out:
# Index(['Average Rating'], dtype='object')

# %%
agentperfom[agentperfom.dtypes[agentperfom.dtypes=='float64'].index]
# Out:
#       Average Rating
# 0               4.11
# 1               3.14
# 2               4.55
# 3               4.71
# 4               3.67
# ...              ...
# 2155            0.00
# 2156            0.00
# 2157            0.00
# 2158            0.00
# 2159            0.00
#
# [2160 rows x 1 columns]

# %%
agentperfom.dtypes
# Out:
# SL No                        int64
# Date                        object
# Agent Name                  object
# Total Chats                  int64
# Average Response Time       object
# Average Resolution Time     object
# Average Rating             float64
# Total Feedback               int64
# dtype: object

# %%
agentperfom.Agent Name  #  how to select when column has white space instead of underscore.??
# Out:
#   Cell In[51], line 1
#     agentperfom.['Agent Name']
#                 ^
# SyntaxError: invalid syntax

# %%
agentperfom.Date
# Out:
# 0       7/30/2022
# 1       7/30/2022
# 2       7/30/2022
# 3       7/30/2022
# 4       7/30/2022
#           ...
# 2155     7/1/2022
# 2156     7/1/2022
# 2157     7/1/2022
# 2158     7/1/2022
# 2159     7/1/2022
# Name: Date, Length: 2160, dtype: object

# %%
agentperfom.Date[0:4]
# Out:
# 0    7/30/2022
# 1    7/30/2022
# 2    7/30/2022
# 3    7/30/2022
# Name: Date, dtype: object

# %%
agentperfom['Date'][0:4]
# Out:
# 0    7/30/2022
# 1    7/30/2022
# 2    7/30/2022
# 3    7/30/2022
# Name: Date, dtype: object

# %%
agentperfom['Date'][0:40:2]
# Out:
# 0     7/30/2022
# 2     7/30/2022
# 4     7/30/2022
# 6     7/30/2022
# 8     7/30/2022
# 10    7/30/2022
# 12    7/30/2022
# 14    7/30/2022
# 16    7/30/2022
# 18    7/30/2022
# 20    7/30/2022
# 22    7/30/2022
# 24    7/30/2022
# 26    7/30/2022
# 28    7/30/2022
# 30    7/30/2022
# 32    7/30/2022
# 34    7/30/2022
# 36    7/30/2022
# 38    7/30/2022
# Name: Date, dtype: object

# %%
agentperfom
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
# to add column and value
agentperfom['Date2'] = 'kumar'

# %%
agentperfom
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
agentperfom.columns
# Out:
# Index(['SL No', 'Date', 'Agent Name', 'Total Chats', 'Average Response Time',
#        'Average Resolution Time', 'Average Rating', 'Total Feedback', 'Date2'],
#       dtype='object')

# %%
agentperfom['Agent Name'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2155    False
# 2156    False
# 2157    False
# 2158    False
# 2159    False
# Name: Agent Name, Length: 2160, dtype: bool

# %%
df = pd.read_csv(r"C:\Users\kumak\iNeuron classes\Resources\Live Class\pandas\pollution.csv")

# %%
df
# Out:
#           No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd     Iws  \
# 0          1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW    1.79
# 1          2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW    4.92
# 2          3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW    6.71
# 3          4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW    9.84
# 4          5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW   12.97
# ...      ...   ...    ...  ...   ...    ...   ...   ...     ...  ...     ...
# 43819  43820  2014     12   31    19    8.0   -23  -2.0  1034.0   NW  231.97
# 43820  43821  2014     12   31    20   10.0   -22  -3.0  1034.0   NW  237.78
# 43821  43822  2014     12   31    21   10.0   -22  -3.0  1034.0   NW  242.70
# 43822  43823  2014     12   31    22    8.0   -22  -4.0  1034.0   NW  246.72
# 43823  43824  2014     12   31    23   12.0   -21  -3.0  1034.0   NW  249.85
#
#        Is  Ir
# 0       0   0
# ...

# %%
df.dtypes
# Out:
# No         int64
# year       int64
# month      int64
# day        int64
# hour       int64
# pm2.5    float64
# DEWP       int64
# TEMP     float64
# PRES     float64
# cbwd      object
# Iws      float64
# Is         int64
# Ir         int64
# dtype: object

# %%
df[df['pm2.5'].isnull()==True]
# Out:
#           No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd     Iws  \
# 0          1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW    1.79
# 1          2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW    4.92
# 2          3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW    6.71
# 3          4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW    9.84
# 4          5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW   12.97
# ...      ...   ...    ...  ...   ...    ...   ...   ...     ...  ...     ...
# 43548  43549  2014     12   20    12    NaN   -18   0.0  1030.0   NW  244.97
# 43549  43550  2014     12   20    13    NaN   -19   1.0  1029.0   NW  249.89
# 43550  43551  2014     12   20    14    NaN   -20   1.0  1029.0   NW  257.04
# 43551  43552  2014     12   20    15    NaN   -20   2.0  1028.0   NW  262.85
# 43552  43553  2014     12   20    16    NaN   -21   1.0  1028.0   NW  270.00
#
#        Is  Ir
# 0       0   0
# ...

# %%
df[df['pm2.5'].isnull()==True]
# Out:
#           No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd     Iws  \
# 0          1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW    1.79
# 1          2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW    4.92
# 2          3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW    6.71
# 3          4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW    9.84
# 4          5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW   12.97
# ...      ...   ...    ...  ...   ...    ...   ...   ...     ...  ...     ...
# 43548  43549  2014     12   20    12    NaN   -18   0.0  1030.0   NW  244.97
# 43549  43550  2014     12   20    13    NaN   -19   1.0  1029.0   NW  249.89
# 43550  43551  2014     12   20    14    NaN   -20   1.0  1029.0   NW  257.04
# 43551  43552  2014     12   20    15    NaN   -20   2.0  1028.0   NW  262.85
# 43552  43553  2014     12   20    16    NaN   -21   1.0  1028.0   NW  270.00
#
#        Is  Ir
# 0       0   0
# ...

# %%
df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  43824.000000  43824.000000  43824.000000  43824.000000  43824.000000
# mean   21912.500000   2012.000000      6.523549     15.727820     11.500000
# std    12651.043435      1.413842      3.448572      8.799425      6.922266
# min        1.000000   2010.000000      1.000000      1.000000      0.000000
# 25%    10956.750000   2011.000000      4.000000      8.000000      5.750000
# 50%    21912.500000   2012.000000      7.000000     16.000000     11.500000
# 75%    32868.250000   2013.000000     10.000000     23.000000     17.250000
# max    43824.000000   2014.000000     12.000000     31.000000     23.000000
#
#               pm2.5          DEWP          TEMP          PRES           Iws  \
# count  41757.000000  43824.000000  43824.000000  43824.000000  43824.000000
# mean      98.613215      1.817246     12.448521   1016.447654     23.889140
# ...

# %%
df.columns
# Out:
# Index(['No', 'year', 'month', 'day', 'hour', 'pm2.5', 'DEWP', 'TEMP', 'PRES',
#        'cbwd', 'Iws', 'Is', 'Ir'],
#       dtype='object')

# %%
df['TEMP']==max(df['TEMP'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 43819    False
# 43820    False
# 43821    False
# 43822    False
# 43823    False
# Name: TEMP, Length: 43824, dtype: bool

# %%
df[df['TEMP']==max(df['TEMP'])]  #  to find out max temp
# Out:
#           No  year  month  day  hour  pm2.5  DEWP  TEMP   PRES cbwd   Iws  Is  \
# 38631  38632  2014      5   29    15   19.0     4  42.0  996.0   NW  5.81   0
#
#        Ir
# 38631   0

# %%
df[df['TEMP']==max(df['TEMP'])]['year']  #  to find out max temp, year
# Out:
# 38631    2014
# Name: year, dtype: int64

# %%
yar = [df[df['TEMP']==max(df['TEMP'])]['year'] ]

# %%
yar
# Out:
# [38631    2014
#  Name: year, dtype: int64]

# %%
df
# Out:
#           No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd     Iws  \
# 0          1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW    1.79
# 1          2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW    4.92
# 2          3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW    6.71
# 3          4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW    9.84
# 4          5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW   12.97
# ...      ...   ...    ...  ...   ...    ...   ...   ...     ...  ...     ...
# 43819  43820  2014     12   31    19    8.0   -23  -2.0  1034.0   NW  231.97
# 43820  43821  2014     12   31    20   10.0   -22  -3.0  1034.0   NW  237.78
# 43821  43822  2014     12   31    21   10.0   -22  -3.0  1034.0   NW  242.70
# 43822  43823  2014     12   31    22    8.0   -22  -4.0  1034.0   NW  246.72
# 43823  43824  2014     12   31    23   12.0   -21  -3.0  1034.0   NW  249.85
#
#        Is  Ir
# 0       0   0
# ...

# %%
df['year']=='2014'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 43819    False
# 43820    False
# 43821    False
# 43822    False
# 43823    False
# Name: year, Length: 43824, dtype: bool

# %%
df[df['year']==2014]
# Out:
#           No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd     Iws  \
# 35064  35065  2014      1    1     0   24.0   -20   7.0  1014.0   NW  143.48
# 35065  35066  2014      1    1     1   53.0   -20   7.0  1013.0   NW  147.50
# 35066  35067  2014      1    1     2   65.0   -20   6.0  1013.0   NW  151.52
# 35067  35068  2014      1    1     3   70.0   -20   6.0  1013.0   NW  153.31
# 35068  35069  2014      1    1     4   79.0   -18   3.0  1012.0   cv    0.89
# ...      ...   ...    ...  ...   ...    ...   ...   ...     ...  ...     ...
# 43819  43820  2014     12   31    19    8.0   -23  -2.0  1034.0   NW  231.97
# 43820  43821  2014     12   31    20   10.0   -22  -3.0  1034.0   NW  237.78
# 43821  43822  2014     12   31    21   10.0   -22  -3.0  1034.0   NW  242.70
# 43822  43823  2014     12   31    22    8.0   -22  -4.0  1034.0   NW  246.72
# 43823  43824  2014     12   31    23   12.0   -21  -3.0  1034.0   NW  249.85
#
#        Is  Ir
# 35064   0   0
# ...

# %%
len(df[df['year']==2014])
# Out:
# 8760

# %%
df[df['hour']>20]
# Out:
#           No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd     Iws  \
# 21        22  2010      1    1    21    NaN   -17  -5.0  1018.0   NW    1.79
# 22        23  2010      1    1    22    NaN   -17  -5.0  1018.0   NW    2.68
# 23        24  2010      1    1    23    NaN   -17  -5.0  1020.0   cv    0.89
# 45        46  2010      1    2    21  164.0    -7  -5.0  1027.0   SE   49.17
# 46        47  2010      1    2    22  156.0    -8  -6.0  1028.0   SE   52.30
# ...      ...   ...    ...  ...   ...    ...   ...   ...     ...  ...     ...
# 43798  43799  2014     12   30    22    8.0   -21   2.0  1025.0   NW   31.73
# 43799  43800  2014     12   30    23   16.0   -22   0.0  1026.0   NW   38.88
# 43821  43822  2014     12   31    21   10.0   -22  -3.0  1034.0   NW  242.70
# 43822  43823  2014     12   31    22    8.0   -22  -4.0  1034.0   NW  246.72
# 43823  43824  2014     12   31    23   12.0   -21  -3.0  1034.0   NW  249.85
#
#        Is  Ir
# 21      0   0
# ...

# %%
df[df['hour']>20]['year']
# Out:
# 21       2010
# 22       2010
# 23       2010
# 45       2010
# 46       2010
#          ...
# 43798    2014
# 43799    2014
# 43821    2014
# 43822    2014
# 43823    2014
# Name: year, Length: 5478, dtype: int64

# %%
df[(df['TEMP'] >2) & (df['DEWP']<0)]
# Out:
#           No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd    Iws  \
# 543      544  2010      1   23    15   17.0   -19   3.0  1024.0   NW  79.15
# 544      545  2010      1   23    16   22.0   -19   3.0  1024.0   NW  86.30
# 564      565  2010      1   24    12    NaN   -16   4.0  1018.0   NW   4.02
# 565      566  2010      1   24    13    NaN   -19   5.0  1017.0   NW  13.85
# 566      567  2010      1   24    14    NaN   -18   5.0  1017.0   NW  22.79
# ...      ...   ...    ...  ...   ...    ...   ...   ...     ...  ...    ...
# 43792  43793  2014     12   30    16   60.0   -14   6.0  1018.0   cv   0.89
# 43793  43794  2014     12   30    17   63.0   -14   5.0  1019.0   NE   1.79
# 43795  43796  2014     12   30    19   35.0    -8   6.0  1021.0   NW   5.81
# 43796  43797  2014     12   30    20   26.0   -11   5.0  1022.0   NW  12.96
# 43797  43798  2014     12   30    21   20.0   -12   4.0  1023.0   NW  21.90
#
#        Is  Ir
# 543     0   0
# 544     0   0
# ...

# %%
df.dtypes
# Out:
# No         int64
# year       int64
# month      int64
# day        int64
# hour       int64
# pm2.5    float64
# DEWP       int64
# TEMP     float64
# PRES     float64
# cbwd      object
# Iws      float64
# Is         int64
# Ir         int64
# dtype: object

# %%
df1 = pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/bank-full.csv", delimiter = ';')

# %%
df1
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
df1.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
df1.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df1.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
df1
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
df1.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
agentperfom[agentperfom.dtypes[agentperfom.dtypes == 'object'].index].describe()

# %%
df1.dtypes[df1.dtypes=='object'].index
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'day_of_week', 'poutcome', 'y'],
#       dtype='object')

# %%
df1[df1.dtypes[df1.dtypes=='object'].index].describe()
# Out:
#            job  marital          education default housing   loan   contact  \
# count    41188    41188              41188   41188   41188  41188     41188
# unique      12        4                  8       3       3      3         2
# top     admin.  married  university.degree      no     yes     no  cellular
# freq     10422    24928              12168   32588   21576  33950     26144
#
#         month day_of_week     poutcome      y
# count   41188       41188        41188  41188
# unique     10           5            3      2
# top       may         thu  nonexistent     no
# freq    13769        8623        35563  36548

# %% [raw]
# When can someone call themself as datascientist?? :D
#     + When that person able to do atleast one project end to end.

# %%
df = pd.read_csv(r"C:\Users\kumak\iNeuron classes\Resources\Live Class\pandas\sales_data_final.csv")

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df['order_date']
# Out:
# 0          1/1/2011
# 1          1/1/2011
# 2          1/1/2011
# 3          1/1/2011
# 4          1/1/2011
#             ...
# 51285    12/31/2014
# 51286    12/31/2014
# 51287    12/31/2014
# 51288    12/31/2014
# 51289    12/31/2014
# Name: order_date, Length: 51290, dtype: object

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
# convert datatype into another

# %%
date = pd.to_datetime(df['order_date'])

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
type(df.order_date)
# Out:
# pandas.core.series.Series

# %%
type(date)
# Out:
# pandas.core.series.Series

# %%
date
# Out:
# 0       2011-01-01
# 1       2011-01-01
# 2       2011-01-01
# 3       2011-01-01
# 4       2011-01-01
#            ...
# 51285   2014-12-31
# 51286   2014-12-31
# 51287   2014-12-31
# 51288   2014-12-31
# 51289   2014-12-31
# Name: order_date, Length: 51290, dtype: datetime64[ns]

# %%
type(date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['coverted_order_date']=date # or pd.to_datetime(df['order_date'])

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df['order_date_year']= df['coverted_order_date'].dt.year

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#                   product_name sales quantity discount   profit  \
# 0          Tenex Lockers, Blue   408        2      0.0  106.140
# ...

# %%
df['order_date_month']= df['coverted_order_date'].dt.month

# %%
df.tail()
# Out:
#              order_id  order_date ship_date       ship_mode     customer_name  \
# 51285  CA-2014-115427  12/31/2014  1/4/2015  Standard Class        Erica Bern
# 51286    MO-2014-2560  12/31/2014  1/5/2015  Standard Class         Liz Preis
# 51287  MX-2014-110527  12/31/2014  1/2/2015    Second Class  Charlotte Melton
# 51288  MX-2014-114783  12/31/2014  1/6/2015  Standard Class     Tamara Dahlen
# 51289  CA-2014-156720  12/31/2014  1/4/2015  Standard Class     Jill Matthias
#
#          segment             state        country  market   region  ... sales  \
# 51285  Corporate        California  United States      US     West  ...    14
# 51286   Consumer  Souss-Massa-Dra        Morocco  Africa   Africa  ...     4
# 51287   Consumer           Managua      Nicaragua   LATAM  Central  ...    26
# 51288   Consumer         Chihuahua         Mexico   LATAM    North  ...     7
# 51289   Consumer          Colorado  United States      US     West  ...     3
#
# ...

# %%
df['order_date_week']= df['coverted_order_date'].dt.isocalendar().week

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... quantity  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...        2
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...        3
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...        4
# 3  Home Office        Stockholm     Sweden      EU    North  ...        3
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...        5
#
#   discount   profit shipping_cost order_priority  year  coverted_order_date  \
# ...

# %%
df['order_date_week']= df['coverted_order_date'].dt.week()
# Out:
# C:\Users\kumak\AppData\Local\Temp\ipykernel_28592\2054504316.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['order_date_week']= df['coverted_order_date'].dt.week()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[178], line 1
# ----> 1 df['order_date_week']= df['coverted_order_date'].dt.week()
#
# TypeError: 'Series' object is not callable

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... quantity  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...        2
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...        3
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...        4
# 3  Home Office        Stockholm     Sweden      EU    North  ...        3
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...        5
#
#   discount   profit shipping_cost order_priority  year  coverted_order_date  \
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'coverted_order_date', 'order_date_year', 'order_date_month',
#        'order_date_week'],
#       dtype='object')

# %%
df[['coverted_order_date', 'order_date_week']]
# Out:
#       coverted_order_date  order_date_week
# 0              2011-01-01               52
# 1              2011-01-01               52
# 2              2011-01-01               52
# 3              2011-01-01               52
# 4              2011-01-01               52
# ...                   ...              ...
# 51285          2014-12-31                1
# 51286          2014-12-31                1
# 51287          2014-12-31                1
# 51288          2014-12-31                1
# 51289          2014-12-31                1
#
# [51290 rows x 2 columns]

# %% [raw]
# why showing 12th month as 1 and 1st month as 52???
#     because, it shows current number of weeks left in year.

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'coverted_order_date', 'order_date_year', 'order_date_month',
#        'order_date_week'],
#       dtype='object')

# %%
df[df['order_date_year'] ==  2014]
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 33759  ES-2014-2774938    1/1/2014  1/3/2014    Second Class
# 33760    IN-2014-47134    1/1/2014  1/5/2014  Standard Class
# 33761  IT-2014-4810734    1/1/2014  1/3/2014    Second Class
# 33762   US-2014-105830    1/1/2014  1/3/2014     First Class
# 33763   CA-2014-160395    1/1/2014  1/7/2014  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name    segment             state        country  market  \
# 33759       Fred Harton   Consumer     Ile-de-France         France      EU
# 33760       Kean Nguyen  Corporate          Victoria      Australia    APAC
# ...

# %%
df[(df['order_date_year'] ==  2014) & (df['order_date_month'] ==  12)]
# Out:
#              order_id  order_date  ship_date       ship_mode  \
# 49137  US-2014-165456   12/1/2014  12/4/2014     First Class
# 49138  US-2014-143014   12/1/2014  12/4/2014     First Class
# 49139  US-2014-120089   12/1/2014  12/1/2014        Same Day
# 49140  CA-2014-111689   12/1/2014  12/3/2014    Second Class
# 49141  CA-2014-142090   12/1/2014  12/8/2014  Standard Class
# ...               ...         ...        ...             ...
# 51285  CA-2014-115427  12/31/2014   1/4/2015  Standard Class
# 51286    MO-2014-2560  12/31/2014   1/5/2015  Standard Class
# 51287  MX-2014-110527  12/31/2014   1/2/2015    Second Class
# 51288  MX-2014-114783  12/31/2014   1/6/2015  Standard Class
# 51289  CA-2014-156720  12/31/2014   1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 49137       Trudy Brown     Consumer      Pennsylvania  United States      US
# ...

# %%
df['order_date_month'].count()
# Out:
# 51290

# %%
df['order_date_month'].value_counts()
# Out:
# 11    6342
# 12    6302
# 9     5975
# 6     5331
# 8     5078
# 10    4490
# 5     3747
# 7     3166
# 4     3057
# 3     3035
# 1     2599
# 2     2168
# Name: order_date_month, dtype: int64

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... quantity  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...        2
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...        3
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...        4
# 3  Home Office        Stockholm     Sweden      EU    North  ...        3
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...        5
#
#   discount   profit shipping_cost order_priority  year  coverted_order_date  \
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'coverted_order_date', 'order_date_year', 'order_date_month',
#        'order_date_week'],
#       dtype='object')

# %%
df['cost_to_company']= df['discount']+df['shipping_cost']

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
# which product the cost to company is high ? or maximum ?

# %%
df[df['cost_to_company']==max(df['cost_to_company'])]
# Out:
#              order_id order_date  ship_date ship_mode customer_name   segment  \
# 13891  CA-2012-124891  7/31/2012  7/31/2012  Same Day   Rick Hansen  Consumer
#
#           state        country market region  ... discount    profit  \
# 13891  New York  United States     US   East  ...      0.0  762.1845
#
#       shipping_cost order_priority  year  coverted_order_date  \
# 13891        933.57       Critical  2012           2012-07-31
#
#        order_date_year  order_date_month  order_date_week cost_to_company
# 13891             2012                 7               31          933.57
#
# [1 rows x 26 columns]

# %%
df[df['cost_to_company']==max(df['cost_to_company'])]['product_name']
# Out:
# 13891    Plantronics CS510 - Over-the-Head monaural Wir...
# Name: product_name, dtype: object

# %%
# how to delete column

# %%
df.drop('cost_to_company')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[202], line 1
# ----> 1 df.drop('cost_to_company')
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
df.drop('cost_to_company', axis = 1)  # droping only in current instances, not permenantly
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... discount  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...      0.0
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...      0.0
# 3  Home Office        Stockholm     Sweden      EU    North  ...      0.5
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
#
#     profit shipping_cost order_priority  year  coverted_order_date  \
# ...

# %%
df4=df.drop('cost_to_company', axis = 1)

# %%
df4
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
# also we can use parameter 'inplace = True' to remove permenatly 
df.drop('cost_to_company', axis = 1, inplace = True)

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... quantity  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...        2
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...        3
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...        4
# 3  Home Office        Stockholm     Sweden      EU    North  ...        3
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...        5
#
#   discount   profit shipping_cost order_priority  year  coverted_order_date  \
# ...

# %%
df.drop(1) # 1st row droped.
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.drop(1, inplace = True) # 1st row droped permenantly
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[215], line 1
# ----> 1 df.drop(1, inplace = True)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %% [raw]
# # filter-out rows
#
# loc , iloc and

# %%
df.loc[[2,3]]
# Out:
#           order_id order_date ship_date     ship_mode  customer_name  \
# 2     HU-2011-1220   1/1/2011  1/5/2011  Second Class  Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011  Second Class   Eugene Moren
#
#        segment      state  country market region  ... quantity discount  \
# 2     Consumer   Budapest  Hungary   EMEA   EMEA  ...        4      0.0
# 3  Home Office  Stockholm   Sweden     EU  North  ...        3      0.5
#
#    profit shipping_cost order_priority  year  coverted_order_date  \
# 2  29.640          8.17           High  2011           2011-01-01
# 3 -26.055          4.82           High  2011           2011-01-01
#
#    order_date_year  order_date_month order_date_week
# 2             2011                 1              52
# 3             2011                 1              52
#
# [2 rows x 25 columns]

# %%
df.loc[2:10]
# Out:
#            order_id order_date ship_date       ship_mode     customer_name  \
# 2      HU-2011-1220   1/1/2011  1/5/2011    Second Class     Annie Thurman
# 3   IT-2011-3647632   1/1/2011  1/5/2011    Second Class      Eugene Moren
# 4     IN-2011-47883   1/1/2011  1/8/2011  Standard Class       Joseph Holt
# 5     IN-2011-47883   1/1/2011  1/8/2011  Standard Class       Joseph Holt
# 6      CA-2011-1510   1/2/2011  1/6/2011  Standard Class   Magdelene Morse
# 7     IN-2011-79397   1/3/2011  1/3/2011        Same Day       Kean Nguyen
# 8     ID-2011-80230   1/3/2011  1/9/2011  Standard Class      Ken Lonsdale
# 9      IZ-2011-4680   1/3/2011  1/7/2011  Standard Class  Lindsay Williams
# 10    IN-2011-65159   1/3/2011  1/7/2011    Second Class      Larry Blacks
#
#         segment             state      country  market          region  ...  \
# 2      Consumer          Budapest      Hungary    EMEA            EMEA  ...
# ...

# %%
df.loc[2:10:2]
# Out:
#          order_id order_date ship_date       ship_mode    customer_name  \
# 2    HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 4   IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 6    CA-2011-1510   1/2/2011  1/6/2011  Standard Class  Magdelene Morse
# 8   ID-2011-80230   1/3/2011  1/9/2011  Standard Class     Ken Lonsdale
# 10  IN-2011-65159   1/3/2011  1/7/2011    Second Class     Larry Blacks
#
#      segment             state      country  market          region  ...  \
# 2   Consumer          Budapest      Hungary    EMEA            EMEA  ...
# 4   Consumer   New South Wales    Australia    APAC         Oceania  ...
# 6   Consumer           Ontario       Canada  Canada          Canada  ...
# 8   Consumer          Auckland  New Zealand    APAC         Oceania  ...
# 10  Consumer  National Capital  Philippines    APAC  Southeast Asia  ...
#
#    quantity discount    profit shipping_cost order_priority  year  \
# ...

# %%
df.loc[0:4][['order_id', 'order_date', 'ship_date']]
# Out:
#           order_id order_date ship_date
# 0     AG-2011-2040   1/1/2011  1/6/2011
# 2     HU-2011-1220   1/1/2011  1/5/2011
# 3  IT-2011-3647632   1/1/2011  1/5/2011
# 4    IN-2011-47883   1/1/2011  1/8/2011

# %%
df.iloc[0:4, 0:3]
# Out:
#           order_id order_date ship_date
# 0     AG-2011-2040   1/1/2011  1/6/2011
# 2     HU-2011-1220   1/1/2011  1/5/2011
# 3  IT-2011-3647632   1/1/2011  1/5/2011
# 4    IN-2011-47883   1/1/2011  1/8/2011

# %%
# loc always takes based on named indexes
# iloc always takes indexes

# %%
df.dtypes
# Out:
# order_id                       object
# order_date                     object
# ship_date                      object
# ship_mode                      object
# customer_name                  object
# segment                        object
# state                          object
# country                        object
# market                         object
# region                         object
# product_id                     object
# category                       object
# sub_category                   object
# product_name                   object
# sales                          object
# quantity                        int64
# discount                      float64
# profit                        float64
# shipping_cost                 float64
# order_priority                 object
# year                            int64
# coverted_order_date    datetime64[ns]
# order_date_year                 int64
# order_date_month                int64
# order_date_week                UInt32
# ...

# %%
df[df['quantity']>5]
# Out:
#               order_id  order_date  ship_date       ship_mode  \
# 12     ES-2011-4869686    1/3/2011   1/7/2011  Standard Class
# 27      MX-2011-111255    1/4/2011   1/9/2011    Second Class
# 29      MX-2011-158771    1/4/2011  1/11/2011  Standard Class
# 31      MX-2011-111255    1/4/2011   1/9/2011    Second Class
# 33      US-2011-136007    1/4/2011  1/11/2011  Standard Class
# ...                ...         ...        ...             ...
# 51253     AO-2014-7730  12/31/2014   1/4/2015  Standard Class
# 51256   CA-2014-143259  12/31/2014   1/4/2015  Standard Class
# 51258     UP-2014-3330  12/31/2014   1/2/2015     First Class
# 51264   MX-2014-110527  12/31/2014   1/2/2015    Second Class
# 51280     TZ-2014-8220  12/31/2014   1/6/2015  Standard Class
#
#             customer_name      segment          state         country  market  \
# 12      Dorothy Dickinson     Consumer        England  United Kingdom      EU
# ...

# %%
df[[df.dtype()=='object']]  # filter out only the dtype 'object'?
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[242], line 1
# ----> 1 df[[df.dtype()=='object']]
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df1
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
df3 = df[df['quantity']>5]

# %%
df3
# Out:
#               order_id  order_date  ship_date       ship_mode  \
# 12     ES-2011-4869686    1/3/2011   1/7/2011  Standard Class
# 27      MX-2011-111255    1/4/2011   1/9/2011    Second Class
# 29      MX-2011-158771    1/4/2011  1/11/2011  Standard Class
# 31      MX-2011-111255    1/4/2011   1/9/2011    Second Class
# 33      US-2011-136007    1/4/2011  1/11/2011  Standard Class
# ...                ...         ...        ...             ...
# 51253     AO-2014-7730  12/31/2014   1/4/2015  Standard Class
# 51256   CA-2014-143259  12/31/2014   1/4/2015  Standard Class
# 51258     UP-2014-3330  12/31/2014   1/2/2015     First Class
# 51264   MX-2014-110527  12/31/2014   1/2/2015    Second Class
# 51280     TZ-2014-8220  12/31/2014   1/6/2015  Standard Class
#
#             customer_name      segment          state         country  market  \
# 12      Dorothy Dickinson     Consumer        England  United Kingdom      EU
# ...

# %%
# drop null values based on column and row ??

df3.dropna() # to remove permenant use 'inplace = True'
# Out:
#               order_id  order_date  ship_date       ship_mode  \
# 12     ES-2011-4869686    1/3/2011   1/7/2011  Standard Class
# 27      MX-2011-111255    1/4/2011   1/9/2011    Second Class
# 29      MX-2011-158771    1/4/2011  1/11/2011  Standard Class
# 31      MX-2011-111255    1/4/2011   1/9/2011    Second Class
# 33      US-2011-136007    1/4/2011  1/11/2011  Standard Class
# ...                ...         ...        ...             ...
# 51253     AO-2014-7730  12/31/2014   1/4/2015  Standard Class
# 51256   CA-2014-143259  12/31/2014   1/4/2015  Standard Class
# 51258     UP-2014-3330  12/31/2014   1/2/2015     First Class
# 51264   MX-2014-110527  12/31/2014   1/2/2015    Second Class
# 51280     TZ-2014-8220  12/31/2014   1/6/2015  Standard Class
#
#             customer_name      segment          state         country  market  \
# 12      Dorothy Dickinson     Consumer        England  United Kingdom      EU
# ...

# %%
df3.dropna(axis = 1)
# Out:
#               order_id  order_date  ship_date       ship_mode  \
# 12     ES-2011-4869686    1/3/2011   1/7/2011  Standard Class
# 27      MX-2011-111255    1/4/2011   1/9/2011    Second Class
# 29      MX-2011-158771    1/4/2011  1/11/2011  Standard Class
# 31      MX-2011-111255    1/4/2011   1/9/2011    Second Class
# 33      US-2011-136007    1/4/2011  1/11/2011  Standard Class
# ...                ...         ...        ...             ...
# 51253     AO-2014-7730  12/31/2014   1/4/2015  Standard Class
# 51256   CA-2014-143259  12/31/2014   1/4/2015  Standard Class
# 51258     UP-2014-3330  12/31/2014   1/2/2015     First Class
# 51264   MX-2014-110527  12/31/2014   1/2/2015    Second Class
# 51280     TZ-2014-8220  12/31/2014   1/6/2015  Standard Class
#
#             customer_name      segment          state         country  market  \
# 12      Dorothy Dickinson     Consumer        England  United Kingdom      EU
# ...

# %%
df3 = pd.read_csv(r"C:\Users\kumak\iNeuron classes\Resources\Live Class\pandas\pollution.csv")

# %%
df3  # df3 origninally has 43824 rows
# Out:
#           No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd     Iws  \
# 0          1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW    1.79
# 1          2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW    4.92
# 2          3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW    6.71
# 3          4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW    9.84
# 4          5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW   12.97
# ...      ...   ...    ...  ...   ...    ...   ...   ...     ...  ...     ...
# 43819  43820  2014     12   31    19    8.0   -23  -2.0  1034.0   NW  231.97
# 43820  43821  2014     12   31    20   10.0   -22  -3.0  1034.0   NW  237.78
# 43821  43822  2014     12   31    21   10.0   -22  -3.0  1034.0   NW  242.70
# 43822  43823  2014     12   31    22    8.0   -22  -4.0  1034.0   NW  246.72
# 43823  43824  2014     12   31    23   12.0   -21  -3.0  1034.0   NW  249.85
#
#        Is  Ir
# 0       0   0
# ...

# %%
df3.dropna()  #  once dropped null values, df3 has 41757  values.
# Out:
#           No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd     Iws  \
# 24        25  2010      1    2     0  129.0   -16  -4.0  1020.0   SE    1.79
# 25        26  2010      1    2     1  148.0   -15  -4.0  1020.0   SE    2.68
# 26        27  2010      1    2     2  159.0   -11  -5.0  1021.0   SE    3.57
# 27        28  2010      1    2     3  181.0    -7  -5.0  1022.0   SE    5.36
# 28        29  2010      1    2     4  138.0    -7  -5.0  1022.0   SE    6.25
# ...      ...   ...    ...  ...   ...    ...   ...   ...     ...  ...     ...
# 43819  43820  2014     12   31    19    8.0   -23  -2.0  1034.0   NW  231.97
# 43820  43821  2014     12   31    20   10.0   -22  -3.0  1034.0   NW  237.78
# 43821  43822  2014     12   31    21   10.0   -22  -3.0  1034.0   NW  242.70
# 43822  43823  2014     12   31    22    8.0   -22  -4.0  1034.0   NW  246.72
# 43823  43824  2014     12   31    23   12.0   -21  -3.0  1034.0   NW  249.85
#
#        Is  Ir
# 24      0   0
# ...

# %%
df3.dropna(axis=1)  # droped one column that has 'NaN' null value
# Out:
#           No  year  month  day  hour  DEWP  TEMP    PRES cbwd     Iws  Is  Ir
# 0          1  2010      1    1     0   -21 -11.0  1021.0   NW    1.79   0   0
# 1          2  2010      1    1     1   -21 -12.0  1020.0   NW    4.92   0   0
# 2          3  2010      1    1     2   -21 -11.0  1019.0   NW    6.71   0   0
# 3          4  2010      1    1     3   -21 -14.0  1019.0   NW    9.84   0   0
# 4          5  2010      1    1     4   -20 -12.0  1018.0   NW   12.97   0   0
# ...      ...   ...    ...  ...   ...   ...   ...     ...  ...     ...  ..  ..
# 43819  43820  2014     12   31    19   -23  -2.0  1034.0   NW  231.97   0   0
# 43820  43821  2014     12   31    20   -22  -3.0  1034.0   NW  237.78   0   0
# 43821  43822  2014     12   31    21   -22  -3.0  1034.0   NW  242.70   0   0
# 43822  43823  2014     12   31    22   -22  -4.0  1034.0   NW  246.72   0   0
# 43823  43824  2014     12   31    23   -21  -3.0  1034.0   NW  249.85   0   0
#
# [43824 rows x 12 columns]

# %%
df3.dropna(thresh = 3)
# Out:
#           No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd     Iws  \
# 0          1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW    1.79
# 1          2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW    4.92
# 2          3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW    6.71
# 3          4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW    9.84
# 4          5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW   12.97
# ...      ...   ...    ...  ...   ...    ...   ...   ...     ...  ...     ...
# 43819  43820  2014     12   31    19    8.0   -23  -2.0  1034.0   NW  231.97
# 43820  43821  2014     12   31    20   10.0   -22  -3.0  1034.0   NW  237.78
# 43821  43822  2014     12   31    21   10.0   -22  -3.0  1034.0   NW  242.70
# 43822  43823  2014     12   31    22    8.0   -22  -4.0  1034.0   NW  246.72
# 43823  43824  2014     12   31    23   12.0   -21  -3.0  1034.0   NW  249.85
#
#        Is  Ir
# 0       0   0
# ...

# %%
df3.fillna(value= 'mani')  # to fill null value into provided value
# Out:
#           No  year  month  day  hour pm2.5  DEWP  TEMP    PRES cbwd     Iws  \
# 0          1  2010      1    1     0  mani   -21 -11.0  1021.0   NW    1.79
# 1          2  2010      1    1     1  mani   -21 -12.0  1020.0   NW    4.92
# 2          3  2010      1    1     2  mani   -21 -11.0  1019.0   NW    6.71
# 3          4  2010      1    1     3  mani   -21 -14.0  1019.0   NW    9.84
# 4          5  2010      1    1     4  mani   -20 -12.0  1018.0   NW   12.97
# ...      ...   ...    ...  ...   ...   ...   ...   ...     ...  ...     ...
# 43819  43820  2014     12   31    19   8.0   -23  -2.0  1034.0   NW  231.97
# 43820  43821  2014     12   31    20  10.0   -22  -3.0  1034.0   NW  237.78
# 43821  43822  2014     12   31    21  10.0   -22  -3.0  1034.0   NW  242.70
# 43822  43823  2014     12   31    22   8.0   -22  -4.0  1034.0   NW  246.72
# 43823  43824  2014     12   31    23  12.0   -21  -3.0  1034.0   NW  249.85
#
#        Is  Ir
# 0       0   0
# 1       0   0
# ...

# %%
df3
# Out:
#           No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd     Iws  \
# 0          1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW    1.79
# 1          2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW    4.92
# 2          3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW    6.71
# 3          4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW    9.84
# 4          5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW   12.97
# ...      ...   ...    ...  ...   ...    ...   ...   ...     ...  ...     ...
# 43819  43820  2014     12   31    19    8.0   -23  -2.0  1034.0   NW  231.97
# 43820  43821  2014     12   31    20   10.0   -22  -3.0  1034.0   NW  237.78
# 43821  43822  2014     12   31    21   10.0   -22  -3.0  1034.0   NW  242.70
# 43822  43823  2014     12   31    22    8.0   -22  -4.0  1034.0   NW  246.72
# 43823  43824  2014     12   31    23   12.0   -21  -3.0  1034.0   NW  249.85
#
#        Is  Ir
# 0       0   0
# ...

# %%
df3.fillna(value = df3['hour'].mean())  # to fille null value into mean of 'hour'
# Out:
#           No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd     Iws  \
# 0          1  2010      1    1     0   11.5   -21 -11.0  1021.0   NW    1.79
# 1          2  2010      1    1     1   11.5   -21 -12.0  1020.0   NW    4.92
# 2          3  2010      1    1     2   11.5   -21 -11.0  1019.0   NW    6.71
# 3          4  2010      1    1     3   11.5   -21 -14.0  1019.0   NW    9.84
# 4          5  2010      1    1     4   11.5   -20 -12.0  1018.0   NW   12.97
# ...      ...   ...    ...  ...   ...    ...   ...   ...     ...  ...     ...
# 43819  43820  2014     12   31    19    8.0   -23  -2.0  1034.0   NW  231.97
# 43820  43821  2014     12   31    20   10.0   -22  -3.0  1034.0   NW  237.78
# 43821  43822  2014     12   31    21   10.0   -22  -3.0  1034.0   NW  242.70
# 43822  43823  2014     12   31    22    8.0   -22  -4.0  1034.0   NW  246.72
# 43823  43824  2014     12   31    23   12.0   -21  -3.0  1034.0   NW  249.85
#
#        Is  Ir
# 0       0   0
# ...

# %%
# group by 

df3.groupby('year')

# %%
df3.groupby('year').mean()
# Out:
# C:\Users\kumak\AppData\Local\Temp\ipykernel_28592\671775609.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df3.groupby('year').mean()
#            No     month        day  hour       pm2.5      DEWP       TEMP  \
# year
# 2010   4380.5  6.526027  15.720548  11.5  104.045730  1.592466  11.632420
# 2011  13140.5  6.526027  15.720548  11.5   99.071340  2.134589  12.565297
# 2012  21912.5  6.513661  15.756831  11.5   90.545871  1.976890  11.967441
# 2013  30684.5  6.526027  15.720548  11.5  101.712376  1.329680  12.399201
# 2014  39444.5  6.526027  15.720548  11.5   97.734557  2.052169  13.679566
#
#              PRES        Iws        Is        Ir
# year
# 2010  1016.330194  28.393053  0.071233  0.267922
# 2011  1017.327283  26.232765  0.051712  0.140525
# ...

# %%
df3.groupby('year')['hour'].mean()
# Out:
# year
# 2010    11.5
# 2011    11.5
# 2012    11.5
# 2013    11.5
# 2014    11.5
# Name: hour, dtype: float64

# %%
df3.groupby('year')['TEMP'].mean()
# Out:
# year
# 2010    11.632420
# 2011    12.565297
# 2012    11.967441
# 2013    12.399201
# 2014    13.679566
# Name: TEMP, dtype: float64

# %%
df3.columns
# Out:
# Index(['No', 'year', 'month', 'day', 'hour', 'pm2.5', 'DEWP', 'TEMP', 'PRES',
#        'cbwd', 'Iws', 'Is', 'Ir'],
#       dtype='object')

# %%
df3[['year', 'hour', 'hour','TEMP' ]]
# Out:
#        year  hour  hour  TEMP
# 0      2010     0     0 -11.0
# 1      2010     1     1 -12.0
# 2      2010     2     2 -11.0
# 3      2010     3     3 -14.0
# 4      2010     4     4 -12.0
# ...     ...   ...   ...   ...
# 43819  2014    19    19  -2.0
# 43820  2014    20    20  -3.0
# 43821  2014    21    21  -3.0
# 43822  2014    22    22  -4.0
# 43823  2014    23    23  -3.0
#
# [43824 rows x 4 columns]

# %%
df3
# Out:
#           No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd     Iws  \
# 0          1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW    1.79
# 1          2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW    4.92
# 2          3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW    6.71
# 3          4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW    9.84
# 4          5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW   12.97
# ...      ...   ...    ...  ...   ...    ...   ...   ...     ...  ...     ...
# 43819  43820  2014     12   31    19    8.0   -23  -2.0  1034.0   NW  231.97
# 43820  43821  2014     12   31    20   10.0   -22  -3.0  1034.0   NW  237.78
# 43821  43822  2014     12   31    21   10.0   -22  -3.0  1034.0   NW  242.70
# 43822  43823  2014     12   31    22    8.0   -22  -4.0  1034.0   NW  246.72
# 43823  43824  2014     12   31    23   12.0   -21  -3.0  1034.0   NW  249.85
#
#        Is  Ir
# 0       0   0
# ...

# %%
df3.dtypes
# Out:
# No         int64
# year       int64
# month      int64
# day        int64
# hour       int64
# pm2.5    float64
# DEWP       int64
# TEMP     float64
# PRES     float64
# cbwd      object
# Iws      float64
# Is         int64
# Ir         int64
# dtype: object

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'coverted_order_date', 'order_date_year', 'order_date_month',
#        'order_date_week'],
#       dtype='object')

# %%
df.sales
# Out:
# 0        408
# 2         66
# 3         45
# 4        114
# 5         55
#         ...
# 51285     14
# 51286      4
# 51287     26
# 51288      7
# 51289      3
# Name: sales, Length: 51289, dtype: object

# %%
df.dtypes
# Out:
# order_id                       object
# order_date                     object
# ship_date                      object
# ship_mode                      object
# customer_name                  object
# segment                        object
# state                          object
# country                        object
# market                         object
# region                         object
# product_id                     object
# category                       object
# sub_category                   object
# product_name                   object
# sales                          object
# quantity                        int64
# discount                      float64
# profit                        float64
# shipping_cost                 float64
# order_priority                 object
# year                            int64
# coverted_order_date    datetime64[ns]
# order_date_year                 int64
# order_date_month                int64
# order_date_week                UInt32
# ...

# %%
df4 = df.sales.str.replace(',', "").astype(int)

# %%
df.dtypes
# Out:
# order_id                       object
# order_date                     object
# ship_date                      object
# ship_mode                      object
# customer_name                  object
# segment                        object
# state                          object
# country                        object
# market                         object
# region                         object
# product_id                     object
# category                       object
# sub_category                   object
# product_name                   object
# sales                          object
# quantity                        int64
# discount                      float64
# profit                        float64
# shipping_cost                 float64
# order_priority                 object
# year                            int64
# coverted_order_date    datetime64[ns]
# order_date_year                 int64
# order_date_month                int64
# order_date_week                UInt32
# ...

# %%
df4
# Out:
# 0        408
# 2         66
# 3         45
# 4        114
# 5         55
#         ...
# 51285     14
# 51286      4
# 51287     26
# 51288      7
# 51289      3
# Name: sales, Length: 51289, dtype: int32

# %%
df4.dtypes
# Out:
# dtype('int32')

# %%
df.sales.str.replace(',', "").astype(int)
# Out:
# 0        408
# 2         66
# 3         45
# 4        114
# 5         55
#         ...
# 51285     14
# 51286      4
# 51287     26
# 51288      7
# 51289      3
# Name: sales, Length: 51289, dtype: int32

# %%
df['sales'] = df.sales.str.replace(',', "").astype(int)

# %%
df['sales']
# Out:
# 0        408
# 2         66
# 3         45
# 4        114
# 5         55
#         ...
# 51285     14
# 51286      4
# 51287     26
# 51288      7
# 51289      3
# Name: sales, Length: 51289, dtype: int32

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'coverted_order_date', 'order_date_year', 'order_date_month',
#        'order_date_week'],
#       dtype='object')

# %%
# analytics

# %%
df.groupby('order_date_year')['sales'].mean()
# Out:
# order_date_year
# 2011    251.127153
# 2012    244.252235
# 2013    246.819335
# 2014    245.282129
# Name: sales, dtype: float64

# %%
df.groupby('order_date_year')['quantity'].sum()
# Out:
# order_date_year
# 2011    31440
# 2012    38111
# 2013    48136
# 2014    60622
# Name: quantity, dtype: int64

# %%
df.groupby('order_date_month')['quantity'].sum()
# Out:
# order_date_month
# 1      8840
# 2      7281
# 3     10481
# 4     10552
# 5     13042
# 6     18119
# 7     10984
# 8     17611
# 9     20542
# 10    16049
# 11    22494
# 12    22314
# Name: quantity, dtype: int64

# %%
df.groupby('order_date_week')['quantity'].sum()
# Out:
# order_date_week
# 1     3136
# 2     1945
# 3     2011
# 4     1966
# 5     1844
# 6     1809
# 7     2029
# 8     1765
# 9     1907
# 10    2210
# 11    2423
# 12    2716
# 13    2343
# 14    2373
# 15    2375
# 16    2654
# 17    2422
# 18    2466
# 19    3119
# 20    2774
# 21    2935
# 22    3449
# 23    4037
# 24    4379
# 25    4215
# 26    4254
# 27    2640
# 28    2633
# 29    2303
# 30    2596
# 31    3305
# 32    3735
# 33    4057
# 34    4220
# 35    3803
# 36    4755
# 37    4857
# 38    4875
# 39    4934
# 40    3816
# 41    3244
# 42    3744
# 43    3469
# 44    4337
# 45    5122
# 46    5383
# 47    5521
# 48    5191
# 49    5200
# 50    4874
# 51    4970
# 52    5169
# Name: quantity, dtype: int64

# %% [raw]
# # TASK
#
#
# > for each Agent .. prepare weekly report of 'average rating' (they work for 5 days a week, & someday agent on leave)
# >
# >

# %%
https://drive.google.com/file/d/1FRnbQqgK6S-mr9StNF5MurSaXhah9uoJ/view?usp=sharing


https://drive.google.com/file/d/11rPJXr-9VoeV2Pi0RSfVehw1tbQOAjLI/view?usp=sharing

https://docs.google.com/spreadsheets/d/1z4EWsGxw0YBQ1-51xZDxYNlB3ngJzg4t/edit?usp=sharing&ouid=118282207943964605599&rtpof=true&sd=true


https://docs.google.com/spreadsheets/d/1z2n8aeFF5GoohQ3KCZw8bKogezpO9l4k/edit?usp=sharing&ouid=118282207943964605599&rtpof=true&sd=true

1 .Find out there avarage rating on weekly basis keep this in a mind that they take two days of leave
2 .Total working days for each agents 
3. Total query that you hvae taken 
4. total Feedback that you have received 
5. a agent name who have average rating between 3.5 to 4 
6 . Agent name who have rating lesss then 3.5 
7 . agent name who have rating more then 4.5 
8 . how many feedaback agents have received more then 4.5 average
9 . average weekly response time for each agent 
10 . average weekely resolution time for each agents 
11 . list of all agents name 
12 . percentage of chat on which they have received a feedback 
13 . Total contributation hour for each and every agents weekly basis 
14. total percentage of active hour for a month 

sunny.savita@ineuron.ai ,sudhanshu@ineuron.ai

deadline of complition of this task is 12 AM IST today 

After that if you will submit your task i wont evaluate it at all , excuses will be given to new 
joiners
